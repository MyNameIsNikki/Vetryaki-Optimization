# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 923.8/923.8 kB 41.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 103.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 83.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 57.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 85.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.87 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 39.1/112.6 GB disk)

# %%
# !mkdir -p /content/drive/MyDrive/Colab_files/wind_turbine_yolo_train

# %%
# %cd /content/drive/MyDrive/Colab_files/wind_turbine_yolo_train
# Out:
# /content/drive/MyDrive/Colab_files/wind_turbine_yolo_train

# %%
# !unzip windturbine_yolov11.zip -d /content/drive/MyDrive/Colab_files/wind_turbine_yolo_train
# Out:
# Archive:  windturbine_yolov11.zip
#   inflating: /content/drive/MyDrive/Colab_files/wind_turbine_yolo_train/README.dataset.txt
#   inflating: /content/drive/MyDrive/Colab_files/wind_turbine_yolo_train/README.roboflow.txt
#   inflating: /content/drive/MyDrive/Colab_files/wind_turbine_yolo_train/data.yaml
#    creating: /content/drive/MyDrive/Colab_files/wind_turbine_yolo_train/test/
#    creating: /content/drive/MyDrive/Colab_files/wind_turbine_yolo_train/test/images/
#  extracting: /content/drive/MyDrive/Colab_files/wind_turbine_yolo_train/test/images/105_68_2560_2048_640_640_0_5184_3888_jpg.rf.781efd3b96e54914fff678259e0dd19d.jpg
#  extracting: /content/drive/MyDrive/Colab_files/wind_turbine_yolo_train/test/images/108_2560_3584_640_640_0_8192_5460_JPG_jpg.rf.ac6a808dbe63b24f804a7ed47ae7a773.jpg
#  extracting: /content/drive/MyDrive/Colab_files/wind_turbine_yolo_train/test/images/123_276_1536_1536_640_640_0_5184_3888_jpg.rf.2272df47b0aa29573b19d75e95fa4c42.jpg
# ...

# %%
# !yolo train model=/content/drive/MyDrive/Colab_files/wind_turbine_yolo_train/yolo11l.pt data=/content/drive/MyDrive/Colab_files/wind_turbine_yolo_train/data.yaml epochs=60 imgsz=640 device=0
# Out:
# Ultralytics 8.3.87 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
